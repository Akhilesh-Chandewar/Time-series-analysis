# %% [markdown]
# ### Import the Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()

# %% [markdown]
# ### Importing the Data

# %%
import os
os.path.exists('/home/user/Desktop/time_series_analysis/data/Index2018.csv')
# Out:
# True

# %%
raw_data = pd.read_csv('../data/Index2018.csv')
raw_data.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp = raw_data.copy()

# %% [markdown]
# ### Examining the Data

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp.isna()
# Out:
#        date    spx    dax   ftse  nikkei
# 0     False  False  False  False   False
# 1     False  False  False  False   False
# 2     False  False  False  False   False
# 3     False  False  False  False   False
# 4     False  False  False  False   False
# ...     ...    ...    ...    ...     ...
# 6264  False  False  False  False   False
# 6265  False  False  False  False   False
# 6266  False  False  False  False   False
# 6267  False  False  False  False   False
# 6268  False  False  False  False   False
#
# [6269 rows x 5 columns]

# %%
df_comp.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# ### Plotting the Data

# %%
df_comp.spx.plot(title='S&P 500 Index Over Time',figsize=(20,5))
# Out:
# <Axes: title={'center': 'S&P 500 Index Over Time'}>

# %%
df_comp.ftse.plot(title='FTSE 100 Index Over Time',figsize=(20,5))
# Out:
# <Axes: title={'center': 'FTSE 100 Index Over Time'}>

# %%
df_comp.spx.plot(title = "S&P500 Prices" , figsize=(20,5))
df_comp.ftse.plot(title = "FTSE Prices" , figsize=(20,5))
plt.title("S&P500 vs FTSE")
# Out:
# Text(0.5, 1.0, 'S&P500 vs FTSE')

# %% [markdown]
# ### The QQ Plot

# %%
import scipy.stats as stats
import pylab as pl

# %%
stats.probplot(df_comp.spx , plot=pl)
plt.title("Q-Q plot for S&P500")
# Out:
# Text(0.5, 1.0, 'Q-Q plot for S&P500')
